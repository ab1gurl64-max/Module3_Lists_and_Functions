# %% [markdown]
# 7.4 create a list called things that contain the string mozzarella, cinderella, and salmonella

# %%
things = ["mozzarella","cinderella","salmonella"]

# %% [markdown]
# 7.5 capitilize the element in things that refers to a person and then print the list

# %%
things[1] = things[1].capitalize()
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.6 make the chessy element of things all uppercase and then print it

# %%
things[0] = things[0].upper()
print
